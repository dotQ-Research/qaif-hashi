# %%
import pygame, heapq, random

# Constants for colors and board settings
BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
RED = (255, 0, 0)
GREEN = (0, 255, 0)
BLUE = (0, 0, 255)

EDGE_PADDING = 32
EDGE_WIDTH = 4
NODE_RADIUS = 16
NODE_SPACING = 64
NODE_BORDER_WIDTH = 2
BOARD_SIZE = 8

# ... (Rest of the code remains the same)

# Tutorial for Hashi Game with Error Correction
print("Welcome to Hashi Game with Error Correction Tutorial!")
print("In this game, your goal is to connect all the nodes on the board while ensuring correct connections.")
print("Let's get started:")

# Step 1: Generating the Initial Board
print("\nStep 1: Generating the Initial Board")
print("A random board with nodes and connections is generated for you.")
print("You can see white circles as nodes and gray lines as possible connections.")

# Step 2: Adding Connections
print("\nStep 2: Adding Connections")
print("To add a connection between two nodes, click on one node and then click on another node.")
print("A valid connection will turn black, while an invalid connection will be cleared.")
print("Remember, each node has a specific number of connections it can have, so choose wisely!")

# Step 3: Error Detection
print("\nStep 3: Error Detection")
print("In this game, you may encounter errors in your connections.")
print("The game will automatically detect and highlight these errors with a red outline.")
print("To correct an error, simply right-click on the erroneous connection to remove it.")

# Step 4: Winning the Game
print("\nStep 4: Winning the Game")
print("Your goal is to connect all nodes while ensuring there are no errors.")
print("When you've successfully connected all nodes without errors, you win the game!")

# Step 5: Additional Controls
print("\nStep 5: Additional Controls")
print("Press F1 to reveal the correct connections (solution).")
print("Press F5 to generate a new random board.")
print("Use Page Up and Page Down keys to increase or decrease the board size.")

# Step 6: Start Playing
print("\nStep 6: Start Playing")
print("Now, you are ready to play Hashi with Error Correction!")
print("Click on nodes to add connections, right-click to remove erroneous connections, and aim to win!")

# Initialize the game
pygame.init()
board = Board()
board.Generate(BOARD_SIZE)
board.SetOptimalScreenMode()
pygame.display.set_caption("Hashi with Error Correction")
clock = pygame.time.Clock()
done = False

while not done:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            done = True
        else:
            board.OnEvent(event)
    board.Update()
    clock.tick(120)
    pygame.display.flip()

pygame.quit()
